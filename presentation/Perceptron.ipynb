# %% [markdown]
# Opérateur logique ET

# %%
from source.adaline import processDataset

processDataset("Datas/table_2_1.csv")
# Out:
# Adaline: 0.01, [-0.493255, 0.988493, 0.993532]
# nb iteration: 1000, mean square error: 0.125024

# %% [markdown]
# Classification linéairement séparable

# %%
processDataset("Datas/table_2_9.csv")
# Out:
# Adaline: 0.01, [-1.59298, -0.490485, 0.44744]
# nb iteration: 1000, mean square error: 0.096394

# %% [markdown]
# Classification non linéairement séparable

# %%
processDataset("Datas/table_2_10.csv")
# Out:
# Adaline: 0.01, [0.099539, -0.231156, 0.320539]
# nb iteration: 1000, mean square error: 0.441701

# %% [markdown]
# Regression linéaire

# %%
from source.perceptron2 import process2_11
process2_11("Datas/table_2_11.csv")
# Out:
# Inputs : [[ 1. 10.]
#  [ 1. 14.]
#  [ 1. 12.]
#  [ 1. 18.]
#  [ 1. 16.]
#  [ 1. 14.]
#  [ 1. 22.]
#  [ 1. 28.]
#  [ 1. 26.]
#  [ 1. 16.]
#  [ 1. 23.]
#  [ 1. 25.]
#  [ 1. 20.]
#  [ 1. 20.]
#  [ 1. 24.]
#  [ 1. 12.]
#  [ 1. 15.]
#  [ 1. 18.]
#  [ 1. 14.]
#  [ 1. 26.]
#  [ 1. 25.]
#  [ 1. 17.]
#  [ 1. 12.]
#  [ 1. 20.]
#  [ 1. 23.]
#  [ 1. 22.]
#  [ 1. 26.]
#  [ 1. 22.]
#  [ 1. 18.]
#  [ 1. 21.]]
# Labels : [ 4.4  5.6  4.6  6.1  6.   7.   6.8 10.6 11.   7.6 10.8 10.   6.5  8.2
#   8.8  5.5  5.   8.   7.8  9.   9.4  8.5  6.4  7.5  9.   8.1  8.2 10.
#   9.1  9. ]
# Erreur moyenne : 0.5599993745333038
